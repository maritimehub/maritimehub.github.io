# %%
import pandas as pd

# %%
df = pd.read_excel('pubs/list.xlsx', sheet_name='Sheet1')

# %%
df
# Out:
#            FORMAT                                              TITLE  \
# 0          Report  Industry practices for sharing information in ...
# 1          Report  Carbon footprint of fisheries – a review of st...
# 2          Report  Alternative fuels and propulsion systems for f...
# 3          Report      Equipment and systems onboard fishing vessels
# 4         Article  Industry practices for sharing sustainability ...
# 5    Book chapter  Refrigeration units in marine vessels: Alterna...
# 6   Master thesis  Energy efficient and climate friendly cooling,...
# 7   Master thesis  Energy efficient CO2 refrigeration units for f...
# 8          Report  Implementation of natural refrigerants on crui...
# 9          Report  Review of environmental indices in the maritim...
# 10        Article  Innovative refrigeration concept for passenger...
# 11        Article  CO2 refrigeration system design and optimizati...
# 12  Master thesis  Thermal energy recovery and storage for a hydr...
# ...

# %%
df
# Out:
#            FORMAT                                              TITLE  \
# 0          Report  Industry practices for sharing information in ...
# 1          Report  Carbon footprint of fisheries – a review of st...
# 2          Report  Alternative fuels and propulsion systems for f...
# 3          Report      Equipment and systems onboard fishing vessels
# 4         Article  Industry practices for sharing sustainability ...
# 5    Book chapter  Refrigeration units in marine vessels: Alterna...
# 6   Master thesis  Energy efficient and climate friendly cooling,...
# 7   Master thesis  Energy efficient CO2 refrigeration units for f...
# 8          Report  Implementation of natural refrigerants on crui...
# 9          Report  Review of environmental indices in the maritim...
# 10        Article  Innovative refrigeration concept for passenger...
# 11        Article  CO2 refrigeration system design and optimizati...
# 12  Master thesis  Thermal energy recovery and storage for a hydr...
# ...

# %%
for index, row in df.iterrows():
    print(string.capwords(row['AUTHOR']))
# Out:
# Andrea Viken Strand, Maitri Thakur
# Cecilia H Gabrielii, Sepideh Jafarzadeh
# Cecilia H Gabrielii, Sepideh Jafarzadeh
# Kristina Norne Widell Guro Møen Tveit, Cecilia Gabrielii, Emily Cowan, Leif Grimsmo, Eirik S. Svendsen
# Andrea Viken Strand, Maitri Thakur, Kristina Norne Widell, Cecilia Gabrielli
# Armin Hafner, Cecilia_x000d_ Gabrielii, Kristina Widell
# Muhammad Zahid Saeed
# Pavel Semaev
# Ángel Álvarez Pardiñas, Cecilia Gabrielii
# Cecilia Gabrielii
# Ángel Á. Pardiñas, Håkon Selvnes, Cecilia Gabrielii, Muhammad Zahid Saeed
# Muhammad Zahid Saeed , Armin Hafner , Cecilia Gabrielii, Ignat Tolstorebrov, Kristina N. Widell
# Vanja Revold Olberg
# Larissa Schaan
# Henrik Andersen
# Magnus Egerdahl
# August Brækken

# %%
import string
